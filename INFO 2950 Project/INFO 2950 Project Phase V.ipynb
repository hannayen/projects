# %% [markdown]
# # INFO 2950 Phase V Final Report

# %% [markdown]
# # Major League Baseball (MLB) Players: Batting Performances, Salaries, and Demographics
#
# In the past couple of decades, MLB players have produced eye-catching contracts as headlines in excess of 200 million dollars have been awarded to some of the best players in the sport. While most of these players continue to perform at their peak levels for years after signing, others become massive financial burdens for teams that end up severely ‘overpaying’ for disappointing results. This research project provides a technical analysis of baseball batters and how their performances or demographics might affect their salaries. All results are subject to change.
#
# ## Research Questions
# - In the MLB, can a player's demographics and batting statistics predict their salary? (Maybe). Which statistics are the most relevant? (Tenure, on-base percentage, and number of games played).
# - Has the importance of having good batting statistics increased over time? (Maybe). Is there a relationship to salary? (Yes).
# - Can we predict how much a player will make the following season based on their previous batting history? (Maybe).
# - Can we determine which players are the most overpaid for their batting production? (Yes, with a limitation).
#
# ## Research Summary
# - We cleaned a dataframe of MLB batters’ hitting statistics, demographics, and salaries to examine if factors like average player performance along with personal data like age and weight affect player’s salaries.
# - In theory, a player’s demographics should not matter as much as their talent and production levels but some of these categories could have implications for athleticism. For example, weight could possibly signify more muscle, to hit balls harder and farther.
# - We searched for potential salary indicators with boxplots and scatterplots to visualize an overview of trends in our data.
# - We applied tools and methodologies learned throughout the course with linear and logistic regression models to address our research questions and found that [insert most significant conclusion]
# - All the results presented here are found within a subset of data that we were constricted to and subject to change as new data gets included and as baseball salaries increase or decrease.
#
#
# ## Background and Context
# Baseball is America’s favorite pastime. While other sports like football, basketball, and even soccer are becoming ever more popular across the country, baseball continues to thrive off its loyal fanbases. As avid Major League Baseball (MLB) fans ourselves, we were interested in conducting a project that revolves around the sport. As college students considering careers, we were curious about the money related to the sport and the salaries of our favorite players. Thus, we used this project to analyze the salaries of baseball players and to visualize a cohesive picture of how the baseball teams reward their top players.
#
# Among sports in general, athletes’ salary has been a controversial topic for decades. Athletes think they need to be paid more while spectators may think athletes are being extremely overpaid. Looking specifically at MLB, we can observe that the dispute over salary is no different, as there is currently a lockout occurring because of salary (players want to be paid more while owners want to pay players less). As of present day there is a minimum annual salary MLB players can receive, but the “best” baseball players make substantially more money than their fellow teammates.
#
# If we take the perspective of a general manager or someone holding a position within MLB front offices it would be incredibly appealing to know which players in the league are actually worth their value versus just being overpaid. If we take the perspective of a MLB player it would be appealing to know how exactly they can improve their pay and be compensated better-if it is even possible at all. It may be the case that in MLB only demographic information influences a player’s salary which means that a player wouldn’t necessarily be able to change anything about themselves to receive a higher salary. Or it could be the case that a player’s batting statistics influence their salary-a skill that can be improved. Our analysis methods will potentially reveal which demographics and batting statistics best predict a player’s salary in the league. Thus, if we were to find that batting statistics are a significant predictor of salary, we could potentially assure that only the ‘best’ players make a larger salary which would satisfy MLB owners and encourage MLB players to continuously play at their best and improve their skills.
#
#
# ## Key Terms and Data Sources
# Our data source is from kaggle (Baseball Databank by Open Source Sports). It is data on baseball players, teams, and games from 1871 to 2015. Some key terms used in our research include player salaries, number of games played, on-base plus slugging percentage,
# country of origin, weight in pounds, a player’s batting hand, a player’s throwing hand, years of tenure, and age of the players.
#
# ## Brief Summary of Findings
# Generally, we found that the number of games, on-base plus slugging percentage, years of tenure, and age of the player were significant predictors of the player’s salary. Meanwhile, the player’s country of birth, weight in pounds, batting hand, and throwing hand were not significant predictors of their salaries. These results should be taken cautiously due to the limitations we explain later in our report.

# %% [markdown]
# ## Data Description
#
# * _What are the observations (rows) and the attributes (columns)?_
#  * In our final dataset that we used for analysis, the observations (rows) represent the baseball players for a specific season they played in and the attributes (columns) are the corresponding batting statistics and demographic information for each baseball player. The dataframe consists of the following attributes:
#    * playerID - the player's name in the the form of a unique player id
#    * yearID - the year of the season
#    * teamID - the team the player is on
#    * G - the number of games a player played (games)
#    * AB - the number of at-bats a player had (at bats)
#    * R - the number of times a player scored (runs)
#    * H - the number of hits (hits)
#    * 2B - the number of doubles which is a two-base hit (doubles)
#    * 3B - the number of triples which is a three-base hit (triples)
#    * HR - the number of homeruns (homeruns)
#    * RBI - the number of players that were able to score when this player hit (runs batted in)
#    * BB - the number of walks (base-on-balls)
#    * SO - the number of strikeouts (strikeouts)
#    * HBP - the number of times a player is hit by a pitch (hit by pitch)
#    * SF - the number of sacrifice flys (sacrifice flys)
#    * OPS - the percentage of on-base plus slugging which is the following equation: OPS = ((H+BB+HBP)/(AB+BB+SF+HBP)) + (((1* 1B)+(2* 2B)+(3* 3B)+(4* HR))/AB) (on-base plus slugging)
#    * salary - the amount of annual income a player makes in dollars
#    * birth_country - 0 if a player is not born in the United States, 1 if a player is born in the United States
#    * weight - the weight of a player
#    * height - the height of a player
#    * bats - 0 if the player is a right-handed batter, 1 if player is a left-handed batter, 2 if player can do both
#    * throws - 0 if the player throws right-handed, 1 if the player throws left-handed
#    * tenure - the number of years a player has played in the MLB
#    * age - how old a player is
#    * overpaid - 0 if a player's salary is not two standard deviations above the mean salary (of the year), 1 if a player's salary is two standard deviations above the mean salary (of the year)
#
# * _Why was this dataset created?_
#  * Our final dataset was created so that we are able to observe general statistics on baseball players and also some information about the teams. We have been curious about some of the questions we are trying to answer in our report such as if we can predict how much a player will make the following season based on their previous batting history? Can we determine which current players are the most overpaid for their batting production and which players are the most underpaid? They are all questions that would be interesting to see the result and through the creation of the dataset we are able to get more information on the questions.
#
# * _Who funded the creation of the dataset? What preprocessing was done, and how did the data come to be in the form that you are using?_
#  * Sean Lahman is an author and journalist who speaks about database journalism, data mining and open-source databases.What started as a one man effort in 1994 has grown tremendously, and now a team of researchers have collected their efforts to make this the largest and most accurate source for baseball statistics available anywhere.
#  * Much of the raw data contained in this database comes from the work of Pete Palmer, the legendary statistician, who has had a hand in most of the baseball encyclopedias published since 1974.
#  * Sean Forman to create and maintain an online encyclopedia at Baseball-Reference.com was a quantum leap for both fans and researchers. The website launched in 2000, providing a user-friendly interface to the Lahman Baseball Database.  Forman and Lahman launched the Baseball Databank in 2001, a group of researchers whose goal was to update and maintain the database as an open source collection available to all.
#  * Ted Turocy updates the main data tables since 2012, automating the work of annual updates and linking historical data to play-by-play accounts compiled by Retrosheet. A handful of researchers have made substantial contributions to maintain this database over the years. Listed alphabetically, they are: Derek Adair, Mike Crain, Kevin Johnson, Rod Nelson, Tom Tango, and Paul Wendt. These folks did much of the heavy lifting, and are largely responsible for the improvements made since 2000.
#  * Salary data was first supplied by Doug Pappas, who passed away during the summer of 2004. He was the leading authority on many subjects, most significantly the financial history of Major League Baseball.
#  * Therefore, we have statistics that are turned into a relational database. Many other people have made significant contributions to the database over the years.
#  * Regarding preprocessing, we downloaded multiple datasets and made sure they were from an accurate and reliable source. We made sure to drop any NaNs in our data and we also deleted some records that we were not going to be using. Some of these were attributes relating to certain baseball statistics and other data that was dropped was of any record of information before 1985. Our data came to be by downloading the original dataset and then dropping and adding some columns. We started by dropping some of the statistics from the dataframe. Specifically, we got rid of the columns stint, lgID, SB, CS, IBB, SH, and GIDP. We kept the ones that we are interested in and relevant to our questions. For instance, SB stands for 'stolen bases' and this is not a batting statistic so we dropped this column. We then continued to save these modified dataframes. **Please refer to our project appendix for a complete overview of our data cleaning process.**
#
# * _What processes might have influenced what data was observed and recorded and what was not?_
#  * Since we are using data that is post 1984, we felt it was reasonable to assume that there are standardized ways that every major league baseball game played used to collect in-game statistics. Regardless of team or location, scorecards are used to explain the details of each at-bat throughout the game. This means that the data we used should be pretty accurate and most likely verified by both teams, as well as by Major League Baseball for official scorekeeping purposes. This also means that more advanced data such as exit velocity of a batted ball, launch angles, expected batting averages, etc could not be recorded (since the technology is post 2015).
#  * For our case, there were a couple factors that influenced the data we  observed and what we chose to leave off our data set. To begin, we selected batting statistics based off of our collective background knowledge of the sport. This means that someone with more or less knowledge of baseball might have chosen different statistics to leave off and to include. Another process that affected our final data set was the changing number of teams throughout the post 1984 data. Since some teams had been added and removed from the MLB between then and 2015, we wanted to only create plots of salaries by team on data that had all the current teams. This means we had to use a subset of our final data between 1998 and 2015 for those specific plots.
#
# * _If people are involved, were they aware of the data collection and if so, what purpose did they expect the data to be used for?_
#  * Since they are players, they should be aware that their statistics are recorded but it is possible that they do not know the existence of this dataset, especially players recorded prior to 2000. The players would probably assume that it’s for any purpose you might want to analyze the statistics for, such as betting and scouting.
#  * In our case, we are aware of the data collection and expected to use the data to conduct research questions.
#
# * _Where can your raw source data be found, if applicable? Provide a link to the raw data (hosted in a Cornell Google Drive or Cornell Box)._
#  * Google Drive: https://drive.google.com/drive/folders/1SRDnliZUPS6jxoZ1ly2K9TEwQI95IVum?usp=sharing
#  * Original: https://www.kaggle.com/open-source-sports/baseball-databank
#
# * _Does the dataset contain all possible instances or is it a sample (not necessarily random) of instances from a larger set?_
#  * This dataset does not contain all of the possible instances because the first official game of baseball in the United States took place in June 1846 in Hoboken, New Jersey. The earliest year that is available in the dataset is 1871. Therefore, for the first 25 years that baseball was officially played no data was recorded. Also, the last year that is available in this dataset is 2015. We are in 2021 which means that a total of six recent years of baseball games statistics are missing.
#  * For our final dataset, there also weren't all the possible instances from the original dataset. We used a final timeline of between 1985 and 2015 because that was the time period between which the salary data was available. Like mentioned earlier, we also had to use a subset of data between 1998 and 2015, when comparing team salaries because not all the teams were the same prior to that period. We also dropped instances (players) based on a couple of different conditions. The first one was having null values, which we found to often mean that the player was actually a pitcher and not a batter. We also dropped players with less than 54 games played because this marks off a third of the season and we felt that it was a good cut off point for players to have a good sample size of how well they performed that season. Fewer games could represent that a player was hurt that year for an extended period of time, or just did not play consistently because they weren’t a starter.

# %% [markdown]
# ## Pre Registration Statement

# %% [markdown]
# ### Analysis Methods
#
# For our project, the two analyses we intend to present will be linear regression and logistic regression. One of our goals is to identify player features in Major League Baseball (MLB) such as height, weight, tenure, birth country, and batting statistics such as on-base plus slugging and strikeouts, which may be good indicators of a player’s salary.
#
# **Linear regression:** The outcome of our linear regression will show the relationship between player features and salary for a given year. The regression will quantify the relative impacts of each feature on salary, and we will be able to observe the strength of the relationships between each feature and salary. Ideally, when looking at the outcome of our linear regression, we want to find that OPS is one of the most significant features because OPS is the sum of a player’s on-base percentage and slugging percentage. To put it in simpler terms, a large OPS indicates that a player performed well on offense in many different aspects for his team. In theory, a larger OPS should translate to a greater salary because this means that the better offensive players are getting paid more than relatively worse offensive players. Additionally, we hope that features such as height, tenure, and birth country show a weak relationship in regards to salary because in theory, since these features are not relevant to a player’s baseball skillset, they should not affect players’ salary. We are looking to perform multiple linear regressions for a variety of years in order to observe whether or not certain features vary in significance over time. Our analysis will allow us to see if the correlation between salary and the batting statistic OPS has increased over time. Furthermore, we want to see that the correlation between salary and a supposed irrelevant feature such as birth country has decreased over time. Seeing if the birth country has some impact on salary would be intriguing to see and we could also possibly determine if that feature’s significance has decreased over time. Regardless of our results being significant or not, our analysis of the linear regression will still be interesting. Significant results indicate which features better predict a player’s salary. If there are no significant features, then we will know that there are probably many other aspects of baseball that may determine how much a player will get paid. Furthermore, by observing which features are significant for each year we perform a linear regression, we will be able to identify whether or not bias exists in MLB and if the most deserving players are being paid accordingly. Taking our analysis one step further, we can use our linear regression to potentially forecast the trend and future values of players’ salaries for the next season, and we will be able to check if our forecast is accurate because there are other datasets available with more recent baseball salary data (post 2015) that we can use to compare our predictions.
#
# **Logistic regression:** We will be using logistic regression to identify which player features determine whether or not players in the MLB are paid appropriately for their batting production. We will be performing two logistic regressions. One will determine whether players are overpaid or not overpaid. The second logistic regression will determine whether players are underpaid or not underpaid. To do this, we will need to calculate a probability threshold for each regression that determines if a player is paid appropriately. Our tentative threshold to determine whether or not a player is overpaid will be the probability that a player’s salary is two standard deviations above the median salary of the season. Similarly, our threshold to determine whether or not a player is underpaid will be the probability that a player’s salary is two standard deviations below the median salary of the season. We will use the same features used in our linear regression (height, weight, tenure, birth country, strikeouts, and the batting statistic on-base plus slugging (OPS), etc.) so that we are able to use the predicted values of the best-fitted line from our linear regression when we convert predicted values into probabilities. Whether or not our results are significant, our analysis of the logistic regression will still be interesting. Significant results will indicate which features are better predictive of whether or not a player is overpaid or underpaid. If there are no significant features, then we will know that there are probably other aspects of baseball that may determine whether or not a player is overpaid or underpaid. Ideally, the logistic regression will help us determine the probability of what type of players are likely to be overpaid or underpaid in MLB. In other words, our logistic regression will potentially identify which features of a player are the most important and which features are not as relevant to salary. For instance, we expect that players with a large OPS have a greater probability to be overpaid.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### **Exploratory Data Analysis**

# %% [markdown]
# We started exploratory data analysis by looking at the distribution of pay for each year in our dataset. We used boxplots that looked at salary grouped by year for this.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
import seaborn as sns
import statsmodels.api as sm

# %%
batting_salaries = pd.read_csv('batting_salaries.csv')
batting = pd.read_csv('batting_final.csv')

# %%
batting_salaries = batting_salaries.drop('Unnamed: 0', axis=1)
batting = batting.drop('Unnamed: 0', axis=1)

# %%
batting_salaries.boxplot(column='salary',by='yearID',figsize=(12,10))
plt.ylabel('salary (in millions of dollars)')
plt.xlabel('year')
plt.title('salary grouped by year')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# These boxplots indicates that there is a general increase in salaries as years increase. Furthermore, the range of the data increases as time passes, resulting in larger boxes with more dispersed whiskers. In addition, as time passes, the outliers become more extreme. In 1985, the outliers are not far from the boxplot. In 2009 and 2010, the most extreme outlier is a player who gets paid around 14 times than the median salary in the league. Looking more closely, we see that the median salary has steadily increased over time, but it looks like the salary increase of the upper quartile (the top 25%) has increased exponentially in comparison.

# %% [markdown]
# Similar to the previous boxplots, we used boxplots that looked at OPS grouped by year in order to look at the distribution of OPS for each year in our dataset.

# %%
batting_salaries.boxplot(column='OPS',by='yearID',figsize=(12,10))
plt.ylabel('OPS')
plt.xlabel('year')
plt.title('OPS grouped by year')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# These boxplots indicate that the median OPS across 1985-2015 generally stay consistent. In addition, The other quartiles and range of OPS does not vary that much either. Our finding makes sense because on average, baseball batting performance shouldn't drastically increase or decrease by year unless there are changes in the rules of the actual game. We expect these outliers because there are always players who exceed league standards. We looked at an outlier in 2004 to double check that our boxplot data was correct. The outlier is Barry Bonds, who had one of the greatest seasons in baseball history with his 1.422 OPS in 2004 which confirms our boxplots.

# %%
batting[batting['OPS'] > 1.4]
# Out:
#       playerID  yearID teamID    G     AB      R      H    2B   3B    HR  \
# 969  bondsba01    2004    SFN  147  373.0  129.0  135.0  27.0  3.0  45.0
#
#        RBI     BB    SO  HBP   SF       OPS
# 969  101.0  232.0  41.0  9.0  3.0  1.421733

# %% [markdown]
# _Conclusion on boxplots:_ The 'Salary grouped by year' boxplot that shows that there is a general increase in salaries as the years become more recent. Furthermore, the spread of the data increases as time passes, resulting in larger boxes with more dispersed whiskers.  The ‘OPS grouped by year’ boxplot shows seemingly consistent data with similar spreads regardless of the year which is probably due to it being an average index for hitters that measure the player’s performance; and it would make sense that it stays mostly constant with new and old players.

# %% [markdown]
# To continue our EDA, we aimed to create a scatterplot that plotted median and mean salaries against each year.

# %%
median_salary = batting_salaries.groupby('yearID').median()['salary'].reset_index()
plt.scatter(median_salary['yearID'],median_salary['salary'])
plt.ylabel('median salary')
plt.xlabel('year')
plt.title('median salary by year')
plt.show()

print('The correlation between year and median salary is {:.2f}.'.format(median_salary['yearID'].corr(median_salary['salary'])))
# Out:
# The correlation between year and median salary is 0.94.

# %%
mean_salary = batting_salaries.groupby('yearID').mean()['salary'].reset_index()
plt.scatter(mean_salary['yearID'],mean_salary['salary'])
plt.ylabel('mean salary')
plt.xlabel('year')
plt.title('mean salary by year')
plt.show()

print('The correlation between year and mean salary is {:.2f}.'.format(mean_salary['yearID'].corr(mean_salary['salary'])))
# Out:
# The correlation between year and mean salary is 0.99.

# %% [markdown]
# We observed that both scatterplots depicted a positive relationship between salary (median and mean) and year. This makes sense because looking at our boxplots, there was a general increase in median across the years we are observing (1985-2015). Specifically, the correlation between median salary and year is .94 and the correlation between mean salary and year is .99, indicating a very strong positive relationship.

# %% [markdown]
# We also plotted the median OPS of players against individual years.

# %%
median_ops = batting_salaries.groupby('yearID').median()['OPS'].reset_index()
plt.scatter(median_ops['yearID'],median_ops['OPS'])
plt.ylabel('median OPS')
plt.xlabel('year')
plt.title('median OPS by year')
plt.show()

print('The correlation between year and median OPS is {:.2f}.'.format(median_ops['yearID'].corr(median_ops['OPS'])))
# Out:
# The correlation between year and median OPS is 0.16.

# %% [markdown]
# Finally, we did the same thing with the mean OPS.

# %%
mean_ops = batting_salaries.groupby('yearID').mean()['OPS'].reset_index()
plt.scatter(mean_ops['yearID'],mean_ops['OPS'])
plt.ylabel('mean OPS')
plt.xlabel('year')
plt.title('mean OPS by year')
plt.show()

print('The correlation between year and mean OPS is {:.2f}.'.format(mean_ops['yearID'].corr(mean_ops['OPS'])))
# Out:
# The correlation between year and mean OPS is 0.21.

# %% [markdown]
# Looking at the both OPS scatterplots, there doesn't appear to be a clear relationship between year and OPS. This makes sense because the boxplots we observed showed that the median generally stayed the same across the years we're observing (1985-2015). More specifically, the correlation between median OPS and year is 0.16 while the correlation between mean OPS and year is .21. This is a very weak positive relationship. We also note that there doesn't seem to be a linear relationship in either OPS scatterplots.

# %% [markdown]
# Conclusion on scatterplots: The median salary v. year and mean salary v. year scatterplots showed an upward trend as time passes. The mean and median OPS by year scatterplots showed no clear trend showing little to no relationship between OPS and year.

# %% [markdown]
# After plotting the means and medians of player OPS and Salary, we wanted to analyze how some individual teams paid their players based on OPS because we know some teams have more funding than other teams. Thus, we created scatter plots to see the mean salaries of four teams per year. We chose mean salary over median salary because our previous correlation findings indicate that the relationship between mean salary and year is stronger (.99 > .94).
#
# We used data from post 1998, as that was when the last team currently in the MLB was added. We chose the Yankees for their consistent ranking as the most valuable baseball franchise. We chose the Marlins, Rays, and Pirates as they have all taken turns being the least valuable baseball franchise during our time period of 1998 - 2015.
#
# More specifically, we chose these teams because the Yankees have been the highest-valued team from 2000 to 2015 and the lowest-valued teams have alternated between the Tampa Bay Rays, Pittsburgh Pirates, and Miami Marlins (min. 2 years each during this span)([Source](https://www.google.com/url?q=https://law.marquette.edu/assets/sports-law/pdf/Values%2520Report%252016.pdf&sa=D&source=docs&ust=1634580732849000&usg=AOvVaw18Y8kJinut3DJkSW7FDh6k)).

# %%
# Yankees
yankeeSalary = batting_salaries.loc[:,['salary','teamID','yearID']]
yankeeSalary = yankeeSalary[yankeeSalary['teamID'] == 'NYA']
meanYankeeSalary = yankeeSalary.groupby('yearID').mean().reset_index()

plt.scatter(mean_salary['yearID'].unique(), meanYankeeSalary['salary'])
plt.ylabel('salary (in tens of millions of dollars)')
plt.xlabel('year')
plt.title('Yankees Team Salary by Year')
plt.xticks(rotation=45)
plt.show()

print('The correlation between year and the Yankees\' mean salary is {:.2f}.'.format(meanYankeeSalary['yearID'].corr(meanYankeeSalary['salary'])))

#Marlins
marlinsSalary = batting_salaries.loc[:,['salary','teamID','yearID']]
marlinsSalary = marlinsSalary[marlinsSalary['teamID'] == 'MIA']
meanMarlinsSalary = marlinsSalary.groupby('yearID').mean().reset_index()

plt.scatter(marlinsSalary['yearID'].unique(), meanMarlinsSalary['salary'])
plt.ylabel('salary (in millions of dollars)')
plt.xlabel('year')
plt.title('Marlins Team Salary by Year')
plt.xticks(rotation=45)
plt.show()

print('The correlation between year and the Marlins\' mean salary is {:.2f}.'.format(meanMarlinsSalary['yearID'].corr(meanMarlinsSalary['salary'])))

#Rays
raysSalary = batting_salaries.loc[:,['salary','teamID','yearID']]
raysSalary = raysSalary[raysSalary['teamID'] == 'TBA']
meanRaysSalary = raysSalary.groupby('yearID').mean().reset_index()

plt.scatter(raysSalary['yearID'].unique(), meanRaysSalary['salary'])
plt.ylabel('salary (in millions of dollars)')
plt.xlabel('year')
plt.title('Rays Team Salary by Year')
plt.xticks(rotation=45)
plt.locator_params(axis='x',nbins=10) # to prevent decimals on x-axis ticks
plt.show()

print('The correlation between year and the Rays\' mean salary is {:.2f}.'.format(meanRaysSalary['yearID'].corr(meanRaysSalary['salary'])))

#Pirates
piratesSalary = batting_salaries.loc[:,['salary','teamID','yearID']]
piratesSalary = piratesSalary[piratesSalary['teamID'] == 'PIT']
meanPiratesSalary = piratesSalary.groupby('yearID').mean().reset_index()

plt.scatter(piratesSalary['yearID'].unique(), meanPiratesSalary['salary'])
plt.ylabel('salary (in millions of dollars)')
plt.xlabel('year')
plt.title('Pirates Team Salary by Year')
plt.xticks(rotation=45)
plt.show()

print('The correlation between year and the Pirates\' mean salary is {:.2f}.'.format(meanPiratesSalary['yearID'].corr(meanPiratesSalary['salary'])))
# Out:
# The correlation between year and the Yankees' mean salary is 0.93.
# The correlation between year and the Marlins' mean salary is 0.54.
# The correlation between year and the Rays' mean salary is 0.70.
# The correlation between year and the Pirates' mean salary is 0.80.

# %% [markdown]
# _Conclusion on team scatterplots:_ The mean team salary of the Yankees and Pirates show a relatively strong positive trend against year. The mean team salaries of the Rays and Marlins also show a positive trend against year but the correlation is less strong. Specifically, the correlation between the Yankees' mean salary and year is .93, the correlation between the Pirates' mean salary and year is .80, the correlation between the Rays' mean salary and year is .70, the correlation between the Marlins' mean salary and year is .54. These trends make sense because as we've seen in general, the mean salary across all of the MLB has increased as years increased. In addition, we noted that the Yankees y-axis is in the tens of millions of dollars, while the other teams y-axis is in the millions of dollars. We observed that the Yankees' correlation was the strongest and they are one of the most well-funded teams in the MLB.

# %% [markdown]
# From visualizations like boxplots and scatterplots, we observed some discernible trends in salaries.

# %% [markdown]
# ### **Multivariate Linear Regression**

# %% [markdown]
# We wanted to first create multiple scatterplots that plotted salary against each predictor. We chose to look specifically at 1985 because we intend to perform a linear regression for this year.

# %%
# year 1985
batting_salaries_1985 = batting_salaries[batting_salaries['yearID']==1985]

for i in range(0, len(batting_salaries_1985.columns), 5):
  sns.pairplot(data = batting_salaries_1985, x_vars = batting_salaries_1985.columns[i:i+5], y_vars=['salary'])

# %% [markdown]
# Out of curiosity, we also chose to look at 2015 because we intend to perform a linear regression for this year as well.

# %%
# year 2015
batting_salaries_2015 = batting_salaries[batting_salaries['yearID']==2015]

for i in range(0, len(batting_salaries_2015.columns), 5):
  sns.pairplot(data = batting_salaries_2015,
               x_vars = batting_salaries_2015.columns[i:i+5],
               y_vars=['salary'])

# %% [markdown]
# We created correlation heatmaps for 1985 and 2015 (the range of years we intend to analyze for our linear and logistic regression) in order to observe the potential statistical relationship between salary and our predictors.

# %%
sns.heatmap(batting_salaries_1985.corr(), center=0, cmap='coolwarm')
plt.tight_layout()
plt.show()

# %%
sns.heatmap(batting_salaries_2015.corr(), center=0, cmap='coolwarm')
plt.tight_layout()
plt.show()

# %% [markdown]
# Using the correlation heatmaps, we decided to keep the variables in our linear regression while not including others. In order to prevent multicolinearity, we included weight as a predictor but did not include height because a larger weight usually indicates a greater height. We did not include any batting statistic that is involved in the OPS calculation because that would also induce multicolinearity. TeamID is not a numerical value, thus we did not include it. We also did not include overpaid, as we intend to use it for our logistic regression.
#
# We kept the following variables as predictors for our linear regression: G, OPS, birth_country, weight, bats, throws, tenure, and age (number of games played, on-base plus slugging percentage, country of origin, weight in pounds, a player’s batting hand, a player’s throwing hand, years of tenure, and age of the players, respectively)

# %%
predictors = ['bats','birth_country','age','throws','G','OPS','weight','tenure']

def initialLinearRegression(year):
    modified_df = batting_salaries[batting_salaries['yearID']==year]
    y = modified_df['salary']
    x = modified_df[predictors]
    x = sm.add_constant(x)
    lin_reg_model = sm.OLS(y,x.astype(float)).fit()
    print(lin_reg_model.summary())
    return lin_reg_model.params

for i in range(1985, 2016, 2):
    initialLinearRegression(i)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.429
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     23.19
# Date:                Tue, 07 Dec 2021   Prob (F-statistic):           2.39e-26
# Time:                        23:39:10   Log-Likelihood:                -3584.2
# No. Observations:                 256   AIC:                             7186.
# Df Residuals:                     247   BIC:                             7218.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -4.584e+05   3.91e+05     -1.172      0.242   -1.23e+06    3.12e+05
# ...

# %% [markdown]
# Looking at the results of these initial linear regression models, we noticed that some of our variables are not significant (according to a threshold of 0.05 to put against p-value). Since we needed a model to test against current data, we wanted a model that was as recent and as efficient as possible. Instead of using a mostly arbitrary value of 0.05 to determine which predictors we should include in our final model, we decided we would use AIC scores to find the best model.

# %% [markdown]
# ### **Improving our Linear Regression**

# %% [markdown]
# We decided to focus solely on creating a linear regression model that is as recent as possible in order to most accurately compare our model to current player data. We developed a function to remove a single predictor in our linear regression model to narrow down the variables by comparing AIC scores of the different variations of our model.

# %%
# 2015 iteration 1
predictors = ['bats','birth_country','age','throws','G','OPS','weight','tenure']

def improvedLinearRegression(year, predictor):
    modified_df = batting_salaries[batting_salaries['yearID']==year]
    y = modified_df['salary']
    x = modified_df[predictors].drop(predictor, axis=1)
    x = sm.add_constant(x)
    lin_reg_model = sm.OLS(y,x.astype(float)).fit()
    print(lin_reg_model.summary())
    return lin_reg_model
    
for i in predictors:
    improvedLinearRegression(2015, i)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     56.18
# Date:                Tue, 07 Dec 2021   Prob (F-statistic):           4.31e-50
# Time:                        23:39:10   Log-Likelihood:                -4871.6
# No. Observations:                 293   AIC:                             9759.
# Df Residuals:                     285   BIC:                             9789.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -1.468e+07   4.71e+06     -3.118      0.002   -2.39e+07   -5.41e+06
# ...

# %% [markdown]
# *2015 Model AIC scores for iteration 1:* <br>
# 9759, predictor removed: bats <br>
# 9759, predictor removed: birth_country <br>
# 9759, predictor removed: age <br>
# 9761, predictor removed: throws <br>
# 9766, predictor removed: G <br>
# 9767, predictor removed: OPS <br>
# 9769, predictor removed: weight <br>
# 9825, predictor removed: tenure <br>
# <br>
# From this, we can see that the best variables to remove are bats, birth_country, and age and the variable to definitely keep is tenure. These make sense because a player's batting stance, country of birth, and age should mostly be irrelevant to their salary (except age but we will elaborate on that later) and years of tenure should matter since veterans are more highly valued in the league. We continue to iterate and see if we can get rid of any other variables or if 9759 the best AIC score we can achieve with this model.

# %%
# 2015 iteration 2
predictors = ['throws','G','OPS','weight','tenure']

final_model_2015 = initialLinearRegression(2015)
for i in predictors:
    improvedLinearRegression(2015, i)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.579
# Model:                            OLS   Adj. R-squared:                  0.571
# Method:                 Least Squares   F-statistic:                     78.84
# Date:                Tue, 07 Dec 2021   Prob (F-statistic):           7.83e-52
# Time:                        23:39:10   Log-Likelihood:                -4871.9
# No. Observations:                 293   AIC:                             9756.
# Df Residuals:                     287   BIC:                             9778.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.722e+07   2.83e+06     -6.075      0.000   -2.28e+07   -1.16e+07
# ...

# %% [markdown]
# *2015 Model AIC scores for iteration 2:* <br>
# 9756, predictor removed: none <br>
# 9756, predictor removed: throws <br>
# 9762, predictor removed: G <br>
# 9761, predictor removed: OPS <br>
# 9764, predictor removed: weight <br>
# 9973, predictor removed: tenure <br>
# <br>
# Here, we conclude that no predictors removed is the best model for our 2015 model. This is because AIC score does not change or increases when we remove other variables. However, we decided that we should try finalizing a 2013 model as well, to make sure 2015 isn't a strange year and 2013 was also a recent year where some variables like weight was clearly insignificant according to p-value.

# %%
# 2013 iteration 1
predictors = ['bats','birth_country','age','throws','G','OPS','weight','tenure']

for i in predictors:
    improvedLinearRegression(2013, i)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.435
# Model:                            OLS   Adj. R-squared:                  0.422
# Method:                 Least Squares   F-statistic:                     31.93
# Date:                Tue, 07 Dec 2021   Prob (F-statistic):           1.06e-32
# Time:                        23:39:10   Log-Likelihood:                -4957.7
# No. Observations:                 298   AIC:                             9931.
# Df Residuals:                     290   BIC:                             9961.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -7.433e+06   4.86e+06     -1.528      0.127    -1.7e+07    2.14e+06
# ...

# %% [markdown]
# *2013 Model AIC scores for iteration 1:* <br>
# 9931, predictor removed: bats <br>
# 9930, predictor removed: birth_country <br>
# 9935, predictor removed: age <br>
# 9930, predictor removed: throws <br>
# 9934, predictor removed: G <br>
# 9958, predictor removed: OPS <br>
# 9930, predictor removed: weight <br>
# 9976, predictor removed: tenure <br>
# <br>
# Once again, we use AIC score to determine which predictors we should get rid of for our best model. Here, we see that we should remove birth country, throws, and weight while tenure consistently stays as a variable to keep. These also make sense since the hand that a player throws a ball and a player's weight shouldn't have a strong relationship with a player's salary. We proceed with another iteration to see if we can remove any more variables.

# %%
# 2013 iteration 2
predictors = ['age','G','OPS','tenure']

final_model_2013 = initialLinearRegression(2013)
for i in predictors:
    improvedLinearRegression(2013, i)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 salary   R-squared:                       0.434
# Model:                            OLS   Adj. R-squared:                  0.426
# Method:                 Least Squares   F-statistic:                     56.14
# Date:                Tue, 07 Dec 2021   Prob (F-statistic):           4.09e-35
# Time:                        23:39:10   Log-Likelihood:                -4958.1
# No. Observations:                 298   AIC:                             9926.
# Df Residuals:                     293   BIC:                             9945.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.709e+06   4.21e+06     -1.357      0.176    -1.4e+07    2.57e+06
# ...

# %% [markdown]
# *2013 Model AIC scores for iteration 2* <br>
# 9926, predictor removed: none <br>
# 9929, predictor removed: age <br>
# 9929, predictor removed: G <br>
# 9958, predictor removed: OPS <br>
# 9971, predictor removed: tenure <br>
# <br>
# We finalize our 2013 model with the predictors: age, G, OPS, and tenure since the AIC scores only increase when we remove any predictors at this point. These two models are what we will use to compare and predict a current player's salary.

# %% [markdown]
# ###### We created our own .csv file of player data from five current players:
# We chose the following five players to run our model through: Giancarlo Stanton, Bryce Harper, Tim Anderson, Mitch Moreland, and Ryan Zimmerman. <br> <br>
# These five players represent a wide range of baseball hitter salaries from 2021. Stanton and Harper were both extremely high paid players making 29 million USD and 28 million USD respectively. Tim Anderson represents a slightly above average paid player at 7.25 million USD. Finally, Mitch Moreland and Ryan Zimmerman both represent lower-paid players at 2.25 million USD and 1 million USD.

# %%
current_data_df = pd.read_csv("MLB2021_Data.csv")
current_data_df
# Out:
#      playerID  throws  age    G    OPS  weight  tenure         salary
# 0    StantonG       0   31  139  0.870     245      12       2.9e+0.7
# 1     HarperB       0   28  141  1.044     210      10  2.803846e+0.7
# 2   AndersonT       0   28  123  0.806     185       6      7.25e+0.6
# 3   MorelandM       1   35   81  0.701     245      12      2.25e+0.6
# 4  ZimmermanR       0   36  110  0.756     215      16         1e+0.6

# %% [markdown]
# Here, we use the coefficients from our models to calculate predicted salary for these five players.

# %%
x1, x2, x3, x4, x5 = final_model_2013
current_data_df['predicted_salary_2013'] = [current_data_df['age'][i] * x2 + current_data_df['G'][i] * x3 + current_data_df['OPS'][i] * x4 + current_data_df['tenure'][i] * x5 for i in range(5)]

x1, x2, x3, x4, x5, x6 = final_model_2015
current_data_df['predicted_salary_2015'] = [current_data_df['throws'][i] * x2 + current_data_df['G'][i] * x3 + current_data_df['OPS'][i] * x4 + current_data_df['weight'][i] * x5 + current_data_df['tenure'][i] * x6 for i in range(5)]

# %%
current_data_df
# Out:
#      playerID  throws  age    G    OPS  weight  tenure         salary  \
# 0    StantonG       0   31  139  0.870     245      12       2.9e+0.7
# 1     HarperB       0   28  141  1.044     210      10  2.803846e+0.7
# 2   AndersonT       0   28  123  0.806     185       6      7.25e+0.6
# 3   MorelandM       1   35   81  0.701     245      12      2.25e+0.6
# 4  ZimmermanR       0   36  110  0.756     215      16         1e+0.6
#
#    predicted_salary_2013  predicted_salary_2015
# 0           1.866627e+07           3.238451e+07
# 1           2.032567e+07           3.011553e+07
# 2           1.217048e+07           2.253660e+07
# 3           1.372069e+07           3.076223e+07
# 4           1.888676e+07           3.419703e+07

# %% [markdown]
# ##### Explanation for current players in linear regression model
#
# After running the multivariate linear regression, we found that our model had varying degrees of success in predicting current player salaries. Our 2013 prediction model (using ‘age’, ‘G’, ‘OPS’, and ‘tenure’) had significantly closer predictions compared to our 2015 prediction model (using ‘throws’, ‘G’, ‘OPS’, ‘weight’, and ‘tenure’).
#
# We theorize that this might be because the 2015 model had too much gravity on columns such as weight, throws and tenure, which might have taken away from more important columns like OPS and games.  The following is an analysis of the current players that we tried to predict in our 2013 prediction model.
#
# Giancarlo Stanton was the 5th highest paid hitter in 2021 with a salary of USD29 million. Our 2013 prediction model shows that based on age, games played, OPS, and tenure, his projected salary was USD18.7 million. The difference of over USD10 million may seem slightly extreme, but it sets a new standard for players in our dataset. Stanton’s OPS in 2021 was also lower than his career average, and would only be considered his 8th best season in his career.
#
# Brycer Harper was also paid very similarly to Stanton at around USD28 million. Our 2013 prediction model shows that his projected salary was USD20.3 million, which is also a good amount lower than his real life contract, but slightly above Stanton’s projection. This also makes sense because Harper was the National League Most Valuable Player (NL MVP) in 2021 with an OPS of 1.044, given to the best player in each league. His OPS was also the highest (best) among all players in baseball for the year.
#
# With Stanton and Harper’s projections setting the standard for our projections. Tim Anderson’s projection of around USD12.2 million also falls in line. He has played relatively less years compared to Stanton and Harper and also showed a lower OPS batting production than both of them. But, he played a good number of games (123), which might be the reason his projection was higher than his real life salary of USD7.25 million.
#
# Mitch Moreland is where our projection model did not make as much sense, as he had by far the lowest OPS (0.701) and games played (81). Yet, he made more money compared to Tim Anderson who batted better and was more available. He also made significantly more money compared to his actual salary (USD13.7 million vs. USD2.25 million). This led us to believe that the model placed a lot of emphasis on age and tenure, as Moreland was one of the older players in the dataset (35) and had 12 years of experience. Looking at Ryan Zimmerman, this theory gets confirmed. Zimmerman had an OPS significantly below Stanton’s and played less games, yet his projected salary was slightly higher at USD18.9 million. On the other hand, his age and tenure was the highest of the players in our set.
#
# As a result, our 2013 prediction model had some success projecting player salaries and being consistent with real-life baseball considerations. However, it might place too much emphasis on age and tenure. These are variables that generally increase with salary in careers, but in sports like baseball, veteran players tend to take pay cuts to stay within the sport as their athletic production and ability deteriorates.

# %% [markdown]
# ### **Logistic Regression**

# %% [markdown]
# Our overall goal with fitting logistic regression is to see if we can predict whether a player is overpaid or not.
#
# First, we created a logistic function in order to be used to calculate probabilities. When we create our model, having this logistic function will be useful.

# %%
# function to calculate logit
def logit(x):
    return np.exp(x) / (np.exp(x) + 1)

# %% [markdown]
# When choosing our predictors to create our logistic regression model, we choose those predictors from our linear regression that were shown to be significant. These predictors that we choose for 2013 were G (games), OPS, tenure, and age. In 2015, the predictors we found to be significant were throws, G (games), OPS, weight, and tenure. All of the predictors in 2013 and 2015 that are used in our models were shown to be independent. When running our linear regression model we also found the correlation values between all of the predictors to see if there were any high numbers between predictors to take into consideration when creating our models. We also did some correlation heatmap with these values to visually see the correlation strength between the predictors. Ultimately, we see that with the predictors we decided to use for our logistic regression model are going to allow for our model to be as accurate as possible.

# %%
# fitting logistic regression model for overpaid players
from sklearn.metrics import classification_report

salary_info_2013 = pd.read_csv('salary_info_2013.csv')

def LogisticRegression2013(year):
    logistic_df = salary_info_2013[salary_info_2013['yearID']==year]
    y = logistic_df['overpaid']
    x = logistic_df[['G','OPS','tenure','age']].values 
    overpaid_model = LogisticRegression().fit(x, y)

    m = overpaid_model.coef_[0][0]
    b = overpaid_model.intercept_[0]
    equation = m * year + b

    print('Year:', year, overpaid_model.coef_, overpaid_model.intercept_)
    print('Probablility of not overpaid players in 2013:', logit(equation))

    y_pred = overpaid_model.predict(x)
    print(classification_report(y, y_pred))

    return

LogisticRegression2013(2013)
# Out:
# Year: 2013 [[ 0.01829089  2.27833239  0.6216605  -0.31393371]] [0.18376175]
# Probablility of not overpaid players in 2013: 1.0
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       223
#            1       0.72      0.51      0.59        75
#
#     accuracy                           0.83       298
#    macro avg       0.78      0.72      0.74       298
# weighted avg       0.82      0.83      0.81       298

# %%
salary_info_2015 = pd.read_csv('salary_info_2015.csv')

def LogisticRegression2015(year):
    logistic_df = salary_info_2015[salary_info_2015['yearID']==year]
    y = logistic_df['overpaid']
    x = logistic_df[['throws','G','OPS','weight','tenure']].values 
    overpaid_model = LogisticRegression().fit(x, y)

    m = overpaid_model.coef_[0][0]
    b = overpaid_model.intercept_[0]
    equation = m * year + b

    print('Year:', year, overpaid_model.coef_, overpaid_model.intercept_)
    print('Probablility of not overpaid players in 2015:', logit(equation))

    y_pred = overpaid_model.predict(x)
    print(classification_report(y, y_pred))
 
    return

LogisticRegression2015(2015)
# Out:
# Year: 2015 [[0.26281091 0.02286856 0.64586735 0.00976308 0.59844533]] [-10.63407855]
# Probablility of not overpaid players in 2015: 1.0
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92       219
#            1       0.78      0.70      0.74        74
#
#     accuracy                           0.87       293
#    macro avg       0.84      0.82      0.83       293
# weighted avg       0.87      0.87      0.87       293

# %% [markdown]
# ### Interpretation for logistic regression:
#
# We found that the probabilities of not being an overpaid player is 0.99 for 2013 and 1 for 2015. Therefore, it is of high probabilty that players are being played at a regular rate instead of being overpaid. Considering both of the two years where we created our models, when looking at the classification report. We had around 220 players in the data frame not being considered overpaid and around 74 being considered overpaid. With our models, we can see that there is a higher percentage of results being considered more accurate with classifying players as not underpaid as there values are in the 0.90s. As for being considered overpaid, these values range from 0.51 to 0.78. This reveals that our model does a better job when considering those players that are overpaid.
#
# When comparing the classification report between the 2013 and 2015 models, we can notice that in general, the precision and recall scores of the 2015 model are greater than the precision and recall scores of the 2013 model. In the 2013 model, we see that the values for not being overpaid are for precision and recall are 0.85 and 0.93. In the 2015 model, we see that the values for not being overpaid are for precision and recall are 0.90 and 0.93. In the 2013 model, we see that the values for being overpaid are for precision and recall are 0.72 and 0.51 while for the 2015 model they are 0.78 and 0.70. It follows that, the f1-scores for the 2015 model are greater than the f1-scores of the 2013 model because precision and recall are used to create the f1-score. Thus, because an f1-score is a measure of a model's accuracy and the printed accuracy of the 2015 model is greater than the printed accuracy of the 2013 model, we can observe that in this case, the 2015 model is a better model for the 2015 data than the 2013 model is for the 2013 data.

# %% [markdown]
# ## Evaluation of Significance
#
# For our linear regression, we modeled it over the years starting from 1985 to 2015 in intervals of 2 years. The correlation coefficient varied over the years, one year our model accounted for almost 58% of the variation in our data, and another year it only accounted for about 33% of the variation in our data. Our model used predictor variables: G, OPS, birth_country, weight, bats, throws, tenure, and age (number of games played, on-base plus slugging percentage,  country of origin, weight in pounds, a player’s batting hand, a player’s throwing hand, years of tenure, and age of the players, respectively)  The statistical significance of these variables also varied with the years, but in general, G, OPS, tenure, and age tended to stay significant. This meant that the number of games, OPS (a measure of a player’s performance), tenure, and age were generally relevant in predicting a player’s salary. Further, it meant that the rest of the variables: birth_country, weight, bats, and throws were not significant predictors for a player’s salary.
#
# We performed multiple logistic regressions in an attempt to model whether or not a player could be considered overpaid or not overpaid. We fitted a logistic regression model using the player's salary for that year as the predictor variable to predict whether the player was being overpaid compared to everyone else. For the ranges of years that we choose, we fitted this model. Within every year that we used, we printed the coefficient and intercept of the fitted model. Using the parameters of the fitted overpaid model, we also calculated the probability of overpaid players by using the logit function. This probability for players being overpaid throughout all of the models was in the same range of 0.49 with a thousandth of a decimal difference. Our logistic model could be improved since our numbers seem to be similar to one another throughout the years. Also, the probability of a player being overpaid in a certain year was around 0.49 which seems to be a bit high for what that value is supposed to represent. For every model we created a scatter plot that would visualize the overpaid and salary variables against our overpaid model. All of our plots look similar in that the predicted probability of overpaid is a straight line through the middle, similar to that of homework 7 where the predicted probability of above average cholesterol did not look as much of a logistic function. As our x from running logit(x) gets bigger, the probability of players being overpaid remains the same. Ultimately, if we were to take further steps, we would improve our model by creating a better linear regression model in order to obtain more accurate results for logistic regression (we would create a better linear regression model by linearly transforming each predictor).

# %% [markdown]
# ## Interpretation and Conclusions
#
# From our analysis, we found that, generally, the following statistics of a MLB player tended to be statistically significant, and thus a good predictor of salary: number of games, on-base plus slugging percentage, years of tenure, and age of the player. In general, a better player should receive a better salary. If we analyze the significance or insignificance of each predictor, we can reason that the results we have found make sense realistically. The number of games a MLB player plays throughout the season is indicative of how good a player he is because if you are a better player, you will get more playing time. On-base plus slugging percentage is a measure of how good of a hitter a player is, and producing runs for your team is a valuable skill. As players' tenure and age increases, their level of play most likely increases because they have gained more experience and skill. All of these predictors have a positive relationship with salary. Therefore, similar to our predictions, we see that the number of games, on-base plus slugging percentage, years of tenure, and age of the player may best predict a player's salary. Meanwhile, the player’s country of birth, weight in pounds, batting hand, and throwing hand were not statistically significant predictors of their salaries. We predicted that none of these features should affect a player's salary because, otherwise, we would recognize the possibility of discrimination within the MLB. Thankfully, in regards to our linear regression, we have found that these predictors are not good indicators of salary- though more extensive research and analysis should be done in order to come to a more definitive conclusion.
#
# Using our multivariate linear regression model, players can observe the factors that may potentially influence their salary. They could use some of these factors to negotiate for better salaries. However, our findings from our analysis are by no means conclusive. Gathering other relevant predictors using more current data would have ultimately allowed us to create a more accurate model; however the data is not easily accessible. With access to more recent data and additional predictors such as the round a player was drafted into the league, the financial status of a player’s team, as well as a player’s agent, we would be able to create a more accurate model that predicts player salary for a given season. Furthermore, we could have analyzed how the COVID-19 pandemic affected salary.
#
# In general, our analysis process and methods could potentially be applied toward other sports leagues such as the National Basketball Association or the National Football League, so that we could potentially identify factors within these other leagues that predict an athlete’s salary.
#
#
# Reflection: To gain a deeper understanding of baseball player salaries in relation to our project, we set out by conducting background research. We found some research that provides background about the prevalence of being overpaid in baseball and how that can compare to our values.  In a research paper by Tyler Wasserman at Syracuse University in 2013, he analyzes the factors that affect how much players are paid and some of these factors are often overlooked. Wasserman used linear regression analysis to determine the relationships between the player’s salaries and the different factors such as a player’s production on the field, player’s age, time of the year the contract was signed, whether the player is a free agent, the team signing of the player, and the player’s agent. He found that the biggest influence on a player’s salary is their talent and production levels. Another important finding was that players who were free agents were paid more according to being able to market . Wasserman found that when talking about a player’s age, younger players have a lower salary due to a restricted market before free agency, followed by players who are free agents at the most desirable age, continued by a decline based on getting older. Ultimately, we can see that when we compare this to our own models, some of our predictors are the same and how they compare to the model from Syracuse University are similar, but some comparisons differ. Some of our shared statistics were a player’s overall performance and their age. Overall, we also found, like Wasserman, that a player’s on field abilities is the most important factor in relation to their salary.

# %% [markdown]
# ## Limitations
#
# Our data only spans from 1985-2015 which is a limited range of years. There is a lot of baseball data that exists before 1985 and after 2015 that our dataset does not have, and therefore, does not take into account when we perform our EDA. Another limiting aspect when considering the years is that when we run linear and logistic regressions, we only use half of the years. This is so we do not have 30 models within each type of regression. Therefore, this does to a certain extent limit our conclusions since we do not have regressions for every single year but only half of the years available in the data set.
# While cleaning our data, we got rid of players who played under 54 games (⅓ of the season) within the span of an individual season because this would give us only players who got a reasonable amount of playing time. However, this might have also eliminated really high-paid  players who were injured for most of the year as well as a lot of low-paid players who don’t get consistent playing time. Thus, we may have gotten rid of a couple data points that would be helpful to our EDA.
# Baseball has a lot of variability and players can have better and worse seasons throughout the lifespan of their contracts, which can make it difficult to assign players an average batting statistic(s). To lessen the variability, we want to look at the season right before a player signs their contract to eliminate season to season variability; however, it could be possible for a player to have a bad season and get paid well the year after if they performed well during their other previous seasons.
# We came to the realization that we had 35 unique team ids but there are only 30 teams in the league. We had to decide if we wanted to have the data for the teams in our time frame starting from 1985 or if we wanted to start our time frame from earlier to include all of the teams in the league now. In the first case, we would have more data concerning the changes over the years, however, we would not be able to include some teams that have been valuable to baseball in recent years. In the second case, we would have more data on the differences between teams and would be able to include all of the teams, however, we would have fewer years available to perform analysis on the changes over the years. We decided we would rather have more team by team differences than a longer time span and therefore settled on the second option. This affects our general conclusions as for most of the data that we analyze starts from 1985 but in regard to analyzing salaries, we used a subset of data that was available starting from 1998.
# What truly defines overpaid? There is no official bound for being overpaid that is universally accepted or calculated for baseball players. As a result, we had to come up with our own bound for this report. Initially, we decided to use two standard deviations as the boundary for being overpaid, because this would represent the top 2.5% of player salaries under a normal distribution. However, we found that the classification report for our logistic regression model was not yielding accurate results. We reasonably deduced that we could just use the median and 75th quartile of players to generate a better set of players compared to the rest of their peers. Regardless, we ultimately cannot have a true quantifiable number of what is measured for a player’s salary to be overpaid.
# Players can have better and worse seasons throughout the lifespan of their contracts, which can make it difficult to know what their true value is (look at season right before they signed the contract to eliminate season to season variability)
# There are limitations on our birth country attributes. We use it as a predictor in our linear and logistic regression, but birth country does not necessarily indicate where a player has grown up, and what resources they have available for training.
# Finally, it is important to note that the statistics we chose don’t necessarily capture a player’s full value (similar to how students having good or bad test scores cannot be used to conclude whether they are good or bad students). Since the main statistic we chose, OPS, was a calculation of multiple other batting variables, certain variables could drive up the final value and hide other weaknesses of a batter’s game. For example, a player could have a high OPS from hitting a lot of homeruns but have low value because he strikes out whenever he is not hitting home runs. This means they could be better or worse than the statistics show. Therefore, we cannot conclude anything about the value of the player in order to stay true to not making assumptions regarding our analysis.
# Key points:
# It is important to note that the statistics we chose don’t necessarily capture a player’s 'value' (similar to how students having good or bad test scores cannot be used to conclude whether they are good or bad students). Therefore, we cannot conclude anything about how good a baseball player is by solely looking at their batting statistics in order to stay true to not making assumptions regarding our analysis.
# Furthermore, it is important to realize that batting statistics aren't the only factor indicative of a player's salary. Our findings absolutely do not apply to pitchers because their salary is determined by their pitching statistics. In addition, many players could be paid well because they are good fielders and perform well on defense. This would make their batting statistics less relevant to their salary. Lastly, some players may be paid well just because they fit well with the team and the team's future goals/motto. Thus, the results of our findings that look at the relationship between batting statistics and salaries is not applicable to every player in the MLB and we absolutely should not be assigning MLB players to a salary solely based on their batting statistics.

# %% [markdown]
# ## Source Code
#
# Github Repository Link: https://github.coecis.cornell.edu/hyy5/info2950project
#
# Where we found current players as of 2021:
# - Salary: https://www.spotrac.com/mlb/contracts/sort-average/limit-2000/
# - Demographic and statistic info: https://www.baseball-reference.com/leagues/majors/2021.shtml

# %% [markdown]
# ## Acknowledgments
#
# The linear regression code we used to perform our regression is from a Cornell course ORIE 3120 Practical Tools for Operations Research, Machine Learning and Data Science. Two of our group members took the course Spring 2021. In addition, we used peer review from discussion to help formulate ideas for our analysis. We also used this website to help us interpret our linear regression results: https://statisticsbyjim.com/regression/interpret-r-squared-regression/.
#
# Background about the expected prevalence of being overpaid in baseball:
# https://surface.syr.edu/cgi/viewcontent.cgi?article=1098&context=honors_capstone

# %% [markdown]
# ## Questions for Reviewers
#
# * How can we better linearly transform a predictor if the scatterplot of salary vs. predictor does not indicate a clear relationship (ex. quadratic, exponential, linear) in the first place?
# * How can we determine whether or not our logistic regression is valid?
# * What is another way we can elevate our project so that our analysis can be even more rigorous and comprehensive?
